# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandan801/Dr.Proton/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-43690778-4d0c-43fa-bd3f-7385d338ee3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43690778-4d0c-43fa-bd3f-7385d338ee3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haberman.csv to haberman (1).csv

# %%
import io 
df=pd.read_csv(io.StringIO(uploaded['haberman.csv'].decode('utf-8')))

# %%
df.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %%
df.count()#total no of data we have
# Out:
# age       306
# year      306
# nodes     306
# status    306
# dtype: int64

# %%
df.count(axis=1)
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 301    4
# 302    4
# 303    4
# 304    4
# 305    4
# Length: 306, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
df['age'].mean()
# Out:
# 52.45751633986928

# %%
df['age'].median()
# Out:
# 52.0

# %%
df.mad()
# Out:
# age       8.865180
# year      2.787005
# nodes     4.790935
# status    0.389273
# dtype: float64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
df.tail()
# Out:
#      age  year  nodes  status
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2

# %%
df.plt(kind='scatter',x=)

# %%
sns.set_style("whitegrid");
sns.pairplot(df)
plt.show()

# %%
print (df.shape[0])
print(df.shape[1])
print(df.iloc[:,-1].value_counts())
print(df.iloc[:,-1].value_counts(normalize=True))#giving us % of data according of status table
# Out:
# 306
# 4
# 1    225
# 2     81
# Name: status, dtype: int64
# 1    0.735294
# 2    0.264706
# Name: status, dtype: float64

# %%
# modify the target column values to be meaningful as well as categorical
df['status'] = df['status'].replace({1:"yes", 2:"no"})

# %%
sns.FacetGrid(df,hue='status',size=5)\
.map(sns.distplot,'year')\
.add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue='status',size=5)\
.map(sns.distplot,'age')\
.add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue='status',size=5)\
.map(sns.distplot,'nodes')\
.add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='status',y='year',data=df)

# %%
sns.violinplot(x='status',y='nodes',data=df)

# %%
df.plot( x='status', y='year', kind='hist')
