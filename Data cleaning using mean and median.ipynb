# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandan801/Dr.Proton/blob/master/Data%20cleaning%20using%20mean%20and%20median.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn 
from google.colab import files 
df=files.upload()
# Out:
#      <input type="file" id="files-b0b327a3-4fde-4ff2-ab06-3ab6f7316499" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0b327a3-4fde-4ff2-ab06-3ab6f7316499">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_submission.csv to sample_submission (1).csv
# Saving test.csv to test (1).csv
# Saving train.csv to train (1).csv

# %%
import io
df_train=pd.read_csv(io.StringIO(df['train.csv'].decode('utf-8')))
df_test=pd.read_csv(io.StringIO(df['test.csv'].decode('utf-8')))
df_sample_submission=pd.read_csv(io.StringIO(df['sample_submission.csv'].decode('utf-8')))

# %%
df_train.head()
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
Null_Data=df_train.isnull().sum()/df_train.shape[0]*100
Null_Data
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
Drop_data=Null_Data[Null_Data>20].keys()
Drop_data
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
New_df_train=df_train.drop(columns=Drop_data)
New_df_train.shape
# Out:
# (1460, 76)

# %%
df_train_2=New_df_train.select_dtypes(include=['int64','float64'])
df_train_2
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %%
plt.figure(figsize=(16,9),)
sns.heatmap(df_train_2)

# %%
df_train_2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
missing_value=[var for var in df_train_2.columns if df_train_2[var].isnull().sum()>0]
missing_value
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# # After the above code we can see and access the missing values of dataset now we've to fill the missing values. So to do it we've to first see data distribution.

# %%
plt.figure(figsize=(10,10))
sns.set()
for i,var in enumerate(missing_value):
  plt.subplot(2,2,i+1)
  sns.distplot(df_train_2[var],bins=25)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# mean and meadian used only when in dataset the missing values are random

# %%
df_train_3=df_train_2.fillna(df_train_2.mean())

# %%
df_train_3.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
sns.set()
for i,var in enumerate(missing_value):
  plt.subplot(2,2,i+1)
  sns.distplot(df_train_2[var],bins=25,kde_kws={'linewidth':8,'color':'red'},label='Original')
  sns.distplot(df_train_3[var],bins=25,kde_kws={'linewidth':8,'color':'green'},label='Mean')
  plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df_train_4=df_train_2.fillna(df_train_2.median())
df_train_4.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
sns.set()
for i,var in enumerate(missing_value):
  plt.subplot(2,2,i+1)
  sns.distplot(df_train_2[var],bins=25,hist=False,kde_kws={'linewidth':8,'color':'red'},label='Original')
  sns.distplot(df_train_3[var],bins=25,hist=False,kde_kws={'linewidth':5,'color':'green'},label='Mean')
  sns.distplot(df_train_4[var],bins=25,hist=False,kde_kws={'linewidth':2,'color':'blue'},label='Median')
  plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df_concat=pd.concat([df_train_2[missing_value],df_train_3[missing_value],df_train_4[missing_value]],axis=1)

# %%
df_concat[df_concat.isnull().any(axis=1)].head()
# Out:
#     LotFrontage  MasVnrArea  GarageYrBlt  LotFrontage  MasVnrArea  \
# 7           NaN       240.0       1973.0    70.049958       240.0
# 12          NaN         0.0       1962.0    70.049958         0.0
# 14          NaN       212.0       1960.0    70.049958       212.0
# 16          NaN       180.0       1970.0    70.049958       180.0
# 24          NaN         0.0       1968.0    70.049958         0.0
#
#     GarageYrBlt  LotFrontage  MasVnrArea  GarageYrBlt
# 7        1973.0         69.0       240.0       1973.0
# 12       1962.0         69.0         0.0       1962.0
# 14       1960.0         69.0       212.0       1960.0
# 16       1970.0         69.0       180.0       1970.0
# 24       1968.0         69.0         0.0       1968.0
